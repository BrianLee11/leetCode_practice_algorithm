# %% [markdown]
# #LeetCode question 69. Sqrt(x)
# - Data structure and algorithm
# - Related topics: math, binary search
# - problem url: https://leetcode.com/problems/sqrtx/
# - solution 1: brute-force
# - creation date: Sunday, July 7, 2024

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **69. Sqrt(x)**
#
# Given a non-negative integer $x$, return the square root of $x$ rounded down to the nearest integer. The returned integer should be **non-negative** as well.
#
# You **must not use** any built-in exponent function or operator.
# - For example, do not use:
#
#
# ```
# pow(x, 0.5) in C++
# x ** 0.5 in Python
# ```

# %% [markdown]
# #Submission to LeetCode: codes

# %%
class Solution(object):
    def mySqrt(self, x):
        """
        :type x: int
        :rtype: int
          Intuition: visit every integer until the correct bound is discovered.
          Time Complexity: O(√x)
          - In the worst case, the loop runs until the upperBound^2 is greater than x,
          - which means the loop executes approximately √x times. Hence, the time complexity is O(√x).
        """
        # solution 1: Try exploring all integers.

        # initialize lower and upper bounds
        lowerBound = 0
        upperBound = 1

        # Loop until we find the correct bounds where lowerBound^2 <= x < upperBound^2
        while not (lowerBound * lowerBound <= x < upperBound * upperBound):
            # Increment both bounds
            lowerBound = lowerBound + 1
            upperBound = upperBound + 1

        # Return the integer part of the square root
        return lowerBound

# %%
# Input: an integer x
# Example:
# Input: 8
# Output: 2
# Explanation: The square root of 8 is approximately 2.82842, so the integer part is 2.
solution = Solution()

result = solution.mySqrt(8)
print(result)
# Out:
# 2

# %% [markdown]
# #Submission succes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Analysis: time complexity
#
# - The time complexity of this solution is O(√x). This is because in the worst-case scenario, the loop runs approximately √x times before finding the correct integer square root.

# %% [markdown]
# # Lesson learned
#
# 1. Brute-force method is almost always tempting. But, is there a more efficient method? Let's try to discover it.
